# %% [markdown]
# # Muon Identification

# %% [markdown]
# Muon identification with the ePIC detector is a hot topic right now. Muons are produced in a range of key interaction channels under investigation including time-like compton scattering (TCS), Vector Meson Production (J/$\psi$ -> $\mu$$\mu$) and beyond standard model searches. The challenge is that ePIC does **NOT** have dedicated muon detection systems.
#
# Without dedicated systems, we must identify muons from charged tracks and signals in the calorimeters and PID detectors that we do have available. The difficulty is that muons are very similar in mass to pions, so misidentification of one as the other is a big issue.

# %% [markdown]
# - $m_{\pi} = 139.57039 MeV/c^{2}$
# - $m_{\mu} = 105.66 MeV/c^{2}$
#
# OK, not exactly the same, but quite close. Enough that with the detector resolution we have in HEP systems, it's an issue.

# %% [markdown]
# To try to reliably identify muons, we'll need to dive into calorimeter/PID/tracking systems and see if we can distinguish muon signals from other particles. Once we do this for "simple", single particle situations, we can mix in other particles and the move to real physics events.
#
# Ultimately, we want to try and quantify how well we can identify muons with ePIC and hopefully end up with a generic, muon finding algorithm. We can quanitfy the detection in a few ways:
#
# - Efficiency
#     - What fraction of muons passing through our system do we detect
# - Purity
#     - Using our muon finding algorithm, what fraction of our "muons" are actually misidentified pions (or other particles)
# - Fake rate
#     - At what rate do we falsely identify non-muon particles as muons?
#
# We can do this for our particle gun case and then for specific physics channels too.

# %% [markdown]
# # Setup

# %% [markdown]
# We will need to either download (or stream) some event files in the following locations:
#
# - /volatile/eic/gbxalex/MuonID/Reco/
#     - Particle gun files
# - /volatile/eic/gbxalex/September2025_JPsi_RecoOut/
#     - Vector meson production files
# - /volatile/eic/sjdkay/EpIC_TCS_mumu_18x275/Reco/
#     - TCS files
#
# We need to run some initial setup commands first. Execute the cells below.

# %% [markdown]
# ## Setup Code Blocks

# %% [markdown]
# ### Optional Cell - Run First if using Google Collab

# %%
# !pip uninstall --yes cmake ## to work around an xrootd compilation issue on virtual machine
# !pip install uproot awkward XRootD numpy pandas matplotlib scipy vector

# %% [markdown]
# ### Non-Optional - Always Run!

# %%
#Import some packages we'll need, specifically, uproot
import uproot as up
import os
import awkward as ak
import numpy as np
import pandas as pd
import scipy
import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib.pylab as plt
import vector
from XRootD import client
from scipy import stats
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib import colors as colours

# %%
plt.rcParams['figure.figsize'] = [8.0, 6.0]
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['xaxis.labellocation'] = 'right'
plt.rcParams['yaxis.labellocation'] = 'top'
SMALL_SIZE = 10
MEDIUM_SIZE = 14
BIGGER_SIZE = 20
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title]
deg2rad = np.pi/180.0

# %%
# See - https://pythonhosted.org/xrootdfs/ - For some details on available commands
# Create XRootD client
eic_server = 'root://dtn-eic.jlab.org/'
fs = client.FileSystem(eic_server)
GunPath = "/volatile/eic/gbxalex/MuonID/Recon/"
VMPath = "/volatile/eic/gbxalex/September2025_JPsi_RecoOut/"
TCSPath = "/volatile/eic/sjdkay/EpIC_TCS_mumu_18x275/Reco/"

# %% [markdown]
# ## Testing Paths

# %% [markdown]
# We can check each path via:

# %%
status, files = fs.dirlist(GunPath)
for entry in files:
    print(entry.name)
# Out:
# proton_20GeV_reconOut.root
# kaonMinus_20GeV_reconOut.root
# piPlus_20GeV_reconOut.root
# MuPiKep_Mixed_RecoOut.root
# muMinus_20GeV_reconOut.root
# piMinus_20GeV_reconOut.root
# electron_20GeV_reconOut.root
# kaonPlus_20GeV_reconOut.root
# muPlus_20GeV_reconOut.root

# %% [markdown]
# We see a list of individual roout files. Each is a single particle type except for "MuPiKep_Mixed_RecoOut.root" - which is a mix of all types.
#
# For vector meson production we have:

# %%
status, files = fs.dirlist(VMPath)
for entry in files:
    print(entry.name)
# Out:
# 10x250ep
# 10x130ep

# %% [markdown]
# Two beam energy combinations, let's check 10x130ep:

# %%
status, files = fs.dirlist(VMPath+"/10x130ep")
for entry in files:
    print(entry.name)
# Out:
# reconOut
# logs
# simOut

# %% [markdown]
# The files in reconOut are what we will need later. Finally, for TCS:

# %%
status, files = fs.dirlist(TCSPath)
for entry in files:
    print(entry.name)
# Out:
# TCS_events_mumu_plus_68_recon.root
# TCS_events_mumu_plus_98_recon.root
# TCS_events_mumu_plus_52_recon.root
# TCS_events_mumu_plus_21_recon.root
# TCS_events_mumu_plus_44_recon.root
# TCS_events_mumu_plus_37_recon.root
# TCS_events_mumu_plus_7_recon.root
# TCS_events_mumu_plus_59_recon.root
# TCS_events_mumu_plus_63_recon.root
# TCS_events_mumu_plus_10_recon.root
# TCS_events_mumu_plus_93_recon.root
# TCS_events_mumu_plus_75_recon.root
# TCS_events_mumu_plus_85_recon.root
# TCS_events_mumu_plus_48_recon.root
# TCS_events_mumu_plus_82_recon.root
# TCS_events_mumu_plus_72_recon.root
# TCS_events_mumu_plus_94_recon.root
# TCS_events_mumu_plus_17_recon.root
# TCS_events_mumu_plus_64_recon.root
# TCS_events_mumu_plus_89_recon.root
# TCS_events_mumu_plus_79_recon.root
# TCS_events_mumu_plus_30_recon.root
# TCS_events_mumu_plus_43_recon.root
# TCS_events_mumu_plus_26_recon.root
# TCS_events_mumu_plus_55_recon.root
# TCS_events_mumu_plus_0_recon.root
# TCS_events_mumu_plus_5_recon.root
# TCS_events_mumu_plus_19_recon.root
# TCS_events_mumu_plus_46_recon.root
# TCS_events_mumu_plus_35_recon.root
# TCS_events_mumu_plus_50_recon.root
# TCS_events_mumu_plus_23_recon.root
# TCS_events_mumu_plus_28_recon.root
# TCS_events_mumu_plus_77_recon.root
# TCS_events_mumu_plus_87_recon.root
# TCS_events_mumu_plus_61_recon.root
# TCS_events_mumu_plus_91_recon.root
# TCS_events_mumu_plus_12_recon.root
# TCS_events_mumu_plus_39_recon.root
# TCS_events_mumu_plus_15_recon.root
# TCS_events_mumu_plus_96_recon.root
# TCS_events_mumu_plus_66_recon.root
# TCS_events_mumu_plus_80_recon.root
# TCS_events_mumu_plus_70_recon.root
# TCS_events_mumu_plus_9_recon.root
# TCS_events_mumu_plus_2_recon.root
# TCS_events_mumu_plus_24_recon.root
# TCS_events_mumu_plus_57_recon.root
# TCS_events_mumu_plus_32_recon.root
# TCS_events_mumu_plus_41_recon.root
# TCS_events_mumu_plus_8_recon.root
# TCS_events_mumu_plus_14_recon.root
# TCS_events_mumu_plus_97_recon.root
# TCS_events_mumu_plus_67_recon.root
# TCS_events_mumu_plus_81_recon.root
# TCS_events_mumu_plus_71_recon.root
# TCS_events_mumu_plus_38_recon.root
# TCS_events_mumu_plus_25_recon.root
# TCS_events_mumu_plus_56_recon.root
# TCS_events_mumu_plus_33_recon.root
# TCS_events_mumu_plus_40_recon.root
# TCS_events_mumu_plus_3_recon.root
# TCS_events_mumu_plus_47_recon.root
# TCS_events_mumu_plus_34_recon.root
# TCS_events_mumu_plus_51_recon.root
# TCS_events_mumu_plus_22_recon.root
# TCS_events_mumu_plus_18_recon.root
# TCS_events_mumu_plus_4_recon.root
# TCS_events_mumu_plus_76_recon.root
# TCS_events_mumu_plus_86_recon.root
# TCS_events_mumu_plus_60_recon.root
# TCS_events_mumu_plus_90_recon.root
# TCS_events_mumu_plus_13_recon.root
# TCS_events_mumu_plus_29_recon.root
# TCS_events_mumu_plus_83_recon.root
# TCS_events_mumu_plus_73_recon.root
# TCS_events_mumu_plus_95_recon.root
# TCS_events_mumu_plus_16_recon.root
# TCS_events_mumu_plus_65_recon.root
# TCS_events_mumu_plus_49_recon.root
# TCS_events_mumu_plus_1_recon.root
# TCS_events_mumu_plus_31_recon.root
# TCS_events_mumu_plus_42_recon.root
# TCS_events_mumu_plus_27_recon.root
# TCS_events_mumu_plus_54_recon.root
# TCS_events_mumu_plus_88_recon.root
# TCS_events_mumu_plus_78_recon.root
# TCS_events_mumu_plus_6_recon.root
# TCS_events_mumu_plus_53_recon.root
# TCS_events_mumu_plus_20_recon.root
# TCS_events_mumu_plus_45_recon.root
# TCS_events_mumu_plus_36_recon.root
# TCS_events_mumu_plus_69_recon.root
# TCS_events_mumu_plus_99_recon.root
# TCS_events_mumu_plus_62_recon.root
# TCS_events_mumu_plus_11_recon.root
# TCS_events_mumu_plus_92_recon.root
# TCS_events_mumu_plus_74_recon.root
# TCS_events_mumu_plus_84_recon.root
# TCS_events_mumu_plus_58_recon.root

# %% [markdown]
# # Streaming Files

# %% [markdown]
# The datasets we have at hand this time are a little large to download and run. Instead, we can stream them. Let's start with a particle gun one. We'll first double check our filesizes here too:

# %%
status, files = fs.dirlist(GunPath)
flist=[]
for entry in files:
    flist.append(entry.name) # Add all of our entries to a new list, flist

for entry in sorted(flist):
    fname = GunPath + entry
    print(entry," File Size: ",(((fs.stat(fname))[1]).size)/(1024**2), "MB")
# Out:
# MuPiKep_Mixed_RecoOut.root  File Size:  9173.820505142212 MB
# electron_20GeV_reconOut.root  File Size:  551.6948347091675 MB
# kaonMinus_20GeV_reconOut.root  File Size:  623.7307968139648 MB
# kaonPlus_20GeV_reconOut.root  File Size:  570.8038845062256 MB
# muMinus_20GeV_reconOut.root  File Size:  604.6560964584351 MB
# muPlus_20GeV_reconOut.root  File Size:  605.3360433578491 MB
# piMinus_20GeV_reconOut.root  File Size:  2883.4351301193237 MB
# piPlus_20GeV_reconOut.root  File Size:  2769.5769052505493 MB
# proton_20GeV_reconOut.root  File Size:  580.133563041687 MB

# %% [markdown]
# We'll choese muPlus_20GeV_reconOut.root for now:

# %%
muPlusFile = eic_server + GunPath + "muPlus_20GeV_reconOut.root"
file=up.open(muPlusFile)
tree = file['events']

# %% [markdown]
# We're now good to go and we can start analysing this as we did previously in the May workshop. We can check our tree branches quickly for our MC branches via:

# %%
tree.keys(filter_name="MC*", recursive=False)
# Out:
# ['MCBeamElectrons_objIdx',
#  'MCBeamProtons_objIdx',
#  'MCNonScatteredElectronAssociations_objIdx',
#  'MCParticles',
#  'MCParticlesHeadOnFrameNoBeamFX',
#  'MCScatteredElectronAssociations_objIdx',
#  'MCScatteredElectrons_objIdx',
#  'MCScatteredProtons_objIdx']

# %% [markdown]
# # Event Display

# %% [markdown]
# To try and understand our events, we will also try the EIC event display with our files. This is a bit of a work in progress, so we'll see how it goes and try to get it working for us!
#
# The event display can be found [here](https://github.com/eic/firebird). There are some instructions on running this and a link on this page to running it in our web browser. We'll need to convert some of our files to the right format.

# %% [markdown]
# # Workspace

# %% [markdown]
# From here on in, this is just space to work. You can start a fresh notebook if you want or just work in new cells below this, it's up to you! To begin with, we'll look at the MC particle distributions and see how our events are actually distributed. We'll start with the muons, then check other particles.

# %%
file.keys()
# Out:
# ['events;19', 'events;18', 'podio_metadata;1']

# %%
file.classnames()
# Out:
# {'events;19': 'TTree', 'events;18': 'TTree', 'podio_metadata;1': 'TTree'}

# %%
tree = file['events']

# %%
tree
# Out:
# <TTree 'events' (923 branches) at 0x7f5a39e23560>

# %%
tree.keys(recursive=False)
# Out:
# ['B0ECalClusterAssociations',
#  '_B0ECalClusterAssociations_rec',
#  '_B0ECalClusterAssociations_sim',
#  'B0ECalClusters',
#  '_B0ECalClusters_clusters',
#  '_B0ECalClusters_hits',
#  '_B0ECalClusters_particleIDs',
#  '_B0ECalClusters_shapeParameters',
#  '_B0ECalClusters_hitContributions',
#  '_B0ECalClusters_subdetectorEnergies',
#  'B0ECalRawHitAssociations',
#  '_B0ECalRawHitAssociations_rawHit',
#  '_B0ECalRawHitAssociations_simHit',
#  'B0ECalRawHits',
#  'B0ECalRecHits',
#  '_B0ECalRecHits_rawHit',
#  'B0TrackerCKFTrackAssociations',
#  '_B0TrackerCKFTrackAssociations_rec',
#  '_B0TrackerCKFTrackAssociations_sim',
#  'B0TrackerCKFTrackParameters',
#  'B0TrackerCKFTrackParametersUnfiltered',
#  'B0TrackerCKFTracks',
#  '_B0TrackerCKFTracks_measurements',
#  '_B0TrackerCKFTracks_tracks',
#  '_B0TrackerCKFTracks_trajectory',
#  'B0TrackerCKFTracksUnfiltered',
#  '_B0TrackerCKFTracksUnfiltered_measurements',
#  '_B0TrackerCKFTracksUnfiltered_tracks',
#  '_B0TrackerCKFTracksUnfiltered_trajectory',
#  'B0TrackerCKFTrackUnfilteredAssociations',
#  '_B0TrackerCKFTrackUnfilteredAssociations_rec',
#  '_B0TrackerCKFTrackUnfilteredAssociations_sim',
#  'B0TrackerCKFTrajectories',
#  '_B0TrackerCKFTrajectories_trackParameters',
#  '_B0TrackerCKFTrajectories_measurements_deprecated',
#  '_B0TrackerCKFTrajectories_outliers_deprecated',
#  '_B0TrackerCKFTrajectories_seed',
#  '_B0TrackerCKFTrajectories_measurementChi2',
#  '_B0TrackerCKFTrajectories_outlierChi2',
#  'B0TrackerCKFTrajectoriesUnfiltered',
#  '_B0TrackerCKFTrajectoriesUnfiltered_trackParameters',
#  '_B0TrackerCKFTrajectoriesUnfiltered_measurements_deprecated',
#  '_B0TrackerCKFTrajectoriesUnfiltered_outliers_deprecated',
#  '_B0TrackerCKFTrajectoriesUnfiltered_seed',
#  '_B0TrackerCKFTrajectoriesUnfiltered_measurementChi2',
#  '_B0TrackerCKFTrajectoriesUnfiltered_outlierChi2',
#  'B0TrackerCKFTruthSeededTrackAssociations',
#  '_B0TrackerCKFTruthSeededTrackAssociations_rec',
#  '_B0TrackerCKFTruthSeededTrackAssociations_sim',
#  'B0TrackerCKFTruthSeededTrackParameters',
#  'B0TrackerCKFTruthSeededTrackParametersUnfiltered',
#  'B0TrackerCKFTruthSeededTracks',
#  '_B0TrackerCKFTruthSeededTracks_measurements',
#  '_B0TrackerCKFTruthSeededTracks_tracks',
#  '_B0TrackerCKFTruthSeededTracks_trajectory',
#  'B0TrackerCKFTruthSeededTracksUnfiltered',
#  '_B0TrackerCKFTruthSeededTracksUnfiltered_measurements',
#  '_B0TrackerCKFTruthSeededTracksUnfiltered_tracks',
#  '_B0TrackerCKFTruthSeededTracksUnfiltered_trajectory',
#  'B0TrackerCKFTruthSeededTrackUnfilteredAssociations',
#  '_B0TrackerCKFTruthSeededTrackUnfilteredAssociations_rec',
#  '_B0TrackerCKFTruthSeededTrackUnfilteredAssociations_sim',
#  'B0TrackerCKFTruthSeededTrajectories',
#  '_B0TrackerCKFTruthSeededTrajectories_trackParameters',
#  '_B0TrackerCKFTruthSeededTrajectories_measurements_deprecated',
#  '_B0TrackerCKFTruthSeededTrajectories_outliers_deprecated',
#  '_B0TrackerCKFTruthSeededTrajectories_seed',
#  '_B0TrackerCKFTruthSeededTrajectories_measurementChi2',
#  '_B0TrackerCKFTruthSeededTrajectories_outlierChi2',
#  'B0TrackerCKFTruthSeededTrajectoriesUnfiltered',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_trackParameters',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_measurements_deprecated',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_outliers_deprecated',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_seed',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_measurementChi2',
#  '_B0TrackerCKFTruthSeededTrajectoriesUnfiltered_outlierChi2',
#  'B0TrackerHits',
#  '_B0TrackerHits_particle',
#  'B0TrackerMeasurements',
#  '_B0TrackerMeasurements_hits',
#  '_B0TrackerMeasurements_weights',
#  'B0TrackerRawHitAssociations',
#  '_B0TrackerRawHitAssociations_rawHit',
#  '_B0TrackerRawHitAssociations_simHit',
#  'B0TrackerRawHits',
#  'B0TrackerRecHits',
#  '_B0TrackerRecHits_rawHit',
#  'B0TrackerSeedingResults',
#  'B0TrackerTruthSeeds_objIdx',
#  'BackwardMPGDEndcapHits',
#  '_BackwardMPGDEndcapHits_particle',
#  'BackwardMPGDEndcapRawHitAssociations',
#  '_BackwardMPGDEndcapRawHitAssociations_rawHit',
#  '_BackwardMPGDEndcapRawHitAssociations_simHit',
#  'BackwardMPGDEndcapRawHits',
#  'BackwardMPGDEndcapRecHits',
#  '_BackwardMPGDEndcapRecHits_rawHit',
#  'CalorimeterTrackProjections',
#  '_CalorimeterTrackProjections_track',
#  '_CalorimeterTrackProjections_points',
#  'CentralAndB0TrackVertices',
#  '_CentralAndB0TrackVertices_associatedParticles',
#  'CentralCKFTrackAssociations',
#  '_CentralCKFTrackAssociations_rec',
#  '_CentralCKFTrackAssociations_sim',
#  'CentralCKFTrackParameters',
#  'CentralCKFTrackParametersUnfiltered',
#  'CentralCKFTracks',
#  '_CentralCKFTracks_measurements',
#  '_CentralCKFTracks_tracks',
#  '_CentralCKFTracks_trajectory',
#  'CentralCKFTracksUnfiltered',
#  '_CentralCKFTracksUnfiltered_measurements',
#  '_CentralCKFTracksUnfiltered_tracks',
#  '_CentralCKFTracksUnfiltered_trajectory',
#  'CentralCKFTrackUnfilteredAssociations',
#  '_CentralCKFTrackUnfilteredAssociations_rec',
#  '_CentralCKFTrackUnfilteredAssociations_sim',
#  'CentralCKFTrajectories',
#  '_CentralCKFTrajectories_trackParameters',
#  '_CentralCKFTrajectories_measurements_deprecated',
#  '_CentralCKFTrajectories_outliers_deprecated',
#  '_CentralCKFTrajectories_seed',
#  '_CentralCKFTrajectories_measurementChi2',
#  '_CentralCKFTrajectories_outlierChi2',
#  'CentralCKFTrajectoriesUnfiltered',
#  '_CentralCKFTrajectoriesUnfiltered_trackParameters',
#  '_CentralCKFTrajectoriesUnfiltered_measurements_deprecated',
#  '_CentralCKFTrajectoriesUnfiltered_outliers_deprecated',
#  '_CentralCKFTrajectoriesUnfiltered_seed',
#  '_CentralCKFTrajectoriesUnfiltered_measurementChi2',
#  '_CentralCKFTrajectoriesUnfiltered_outlierChi2',
#  'CentralCKFTruthSeededTrackAssociations',
#  '_CentralCKFTruthSeededTrackAssociations_rec',
#  '_CentralCKFTruthSeededTrackAssociations_sim',
#  'CentralCKFTruthSeededTrackParameters',
#  'CentralCKFTruthSeededTrackParametersUnfiltered',
#  'CentralCKFTruthSeededTracks',
#  '_CentralCKFTruthSeededTracks_measurements',
#  '_CentralCKFTruthSeededTracks_tracks',
#  '_CentralCKFTruthSeededTracks_trajectory',
#  'CentralCKFTruthSeededTracksUnfiltered',
#  '_CentralCKFTruthSeededTracksUnfiltered_measurements',
#  '_CentralCKFTruthSeededTracksUnfiltered_tracks',
#  '_CentralCKFTruthSeededTracksUnfiltered_trajectory',
#  'CentralCKFTruthSeededTrackUnfilteredAssociations',
#  '_CentralCKFTruthSeededTrackUnfilteredAssociations_rec',
#  '_CentralCKFTruthSeededTrackUnfilteredAssociations_sim',
#  'CentralCKFTruthSeededTrajectories',
#  '_CentralCKFTruthSeededTrajectories_trackParameters',
#  '_CentralCKFTruthSeededTrajectories_measurements_deprecated',
#  '_CentralCKFTruthSeededTrajectories_outliers_deprecated',
#  '_CentralCKFTruthSeededTrajectories_seed',
#  '_CentralCKFTruthSeededTrajectories_measurementChi2',
#  '_CentralCKFTruthSeededTrajectories_outlierChi2',
#  'CentralCKFTruthSeededTrajectoriesUnfiltered',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_trackParameters',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_measurements_deprecated',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_outliers_deprecated',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_seed',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_measurementChi2',
#  '_CentralCKFTruthSeededTrajectoriesUnfiltered_outlierChi2',
#  'CentralTrackerMeasurements',
#  '_CentralTrackerMeasurements_hits',
#  '_CentralTrackerMeasurements_weights',
#  'CentralTrackerTruthSeeds_objIdx',
#  'CentralTrackingRawHitAssociations_objIdx',
#  'CentralTrackingRecHits_objIdx',
#  'CentralTrackSeedingResults',
#  'CentralTrackSegments',
#  '_CentralTrackSegments_track',
#  '_CentralTrackSegments_points',
#  'CentralTrackVertices',
#  '_CentralTrackVertices_associatedParticles',
#  'CombinedTOFParticleIDs',
#  '_CombinedTOFParticleIDs_particle',
#  '_CombinedTOFParticleIDs_parameters',
#  'CombinedTOFTruthSeededParticleIDs',
#  '_CombinedTOFTruthSeededParticleIDs_particle',
#  '_CombinedTOFTruthSeededParticleIDs_parameters',
#  'DIRCParticleIDs',
#  '_DIRCParticleIDs_particle',
#  '_DIRCParticleIDs_parameters',
#  'DIRCRawHits',
#  'DIRCTruthSeededParticleIDs',
#  '_DIRCTruthSeededParticleIDs_particle',
#  '_DIRCTruthSeededParticleIDs_parameters',
#  'DRICHAerogelIrtCherenkovParticleID',
#  '_DRICHAerogelIrtCherenkovParticleID_rawHitAssociations',
#  '_DRICHAerogelIrtCherenkovParticleID_chargedParticle',
#  '_DRICHAerogelIrtCherenkovParticleID_hypotheses',
#  '_DRICHAerogelIrtCherenkovParticleID_thetaPhiPhotons',
#  'DRICHAerogelTracks',
#  '_DRICHAerogelTracks_track',
#  '_DRICHAerogelTracks_points',
#  'DRICHGasIrtCherenkovParticleID',
#  '_DRICHGasIrtCherenkovParticleID_rawHitAssociations',
#  '_DRICHGasIrtCherenkovParticleID_chargedParticle',
#  '_DRICHGasIrtCherenkovParticleID_hypotheses',
#  '_DRICHGasIrtCherenkovParticleID_thetaPhiPhotons',
#  'DRICHGasTracks',
#  '_DRICHGasTracks_track',
#  '_DRICHGasTracks_points',
#  'DRICHParticleIDs',
#  '_DRICHParticleIDs_particle',
#  '_DRICHParticleIDs_parameters',
#  'DRICHRawHits',
#  'DRICHRawHitsAssociations',
#  '_DRICHRawHitsAssociations_rawHit',
#  '_DRICHRawHitsAssociations_simHit',
#  'DRICHTruthSeededParticleIDs',
#  '_DRICHTruthSeededParticleIDs_particle',
#  '_DRICHTruthSeededParticleIDs_parameters',
#  'EcalBarrelClusterAssociations',
#  '_EcalBarrelClusterAssociations_rec',
#  '_EcalBarrelClusterAssociations_sim',
#  'EcalBarrelClusters',
#  '_EcalBarrelClusters_clusters',
#  '_EcalBarrelClusters_hits',
#  '_EcalBarrelClusters_particleIDs',
#  '_EcalBarrelClusters_shapeParameters',
#  '_EcalBarrelClusters_hitContributions',
#  '_EcalBarrelClusters_subdetectorEnergies',
#  'EcalBarrelImagingClusterAssociations',
#  '_EcalBarrelImagingClusterAssociations_rec',
#  '_EcalBarrelImagingClusterAssociations_sim',
#  'EcalBarrelImagingClusters',
#  '_EcalBarrelImagingClusters_clusters',
#  '_EcalBarrelImagingClusters_hits',
#  '_EcalBarrelImagingClusters_particleIDs',
#  '_EcalBarrelImagingClusters_shapeParameters',
#  '_EcalBarrelImagingClusters_hitContributions',
#  '_EcalBarrelImagingClusters_subdetectorEnergies',
#  'EcalBarrelImagingRawHitAssociations',
#  '_EcalBarrelImagingRawHitAssociations_rawHit',
#  '_EcalBarrelImagingRawHitAssociations_simHit',
#  'EcalBarrelImagingRawHits',
#  'EcalBarrelImagingRecHits',
#  '_EcalBarrelImagingRecHits_rawHit',
#  'EcalBarrelScFiClusterAssociations',
#  '_EcalBarrelScFiClusterAssociations_rec',
#  '_EcalBarrelScFiClusterAssociations_sim',
#  'EcalBarrelScFiClusters',
#  '_EcalBarrelScFiClusters_clusters',
#  '_EcalBarrelScFiClusters_hits',
#  '_EcalBarrelScFiClusters_particleIDs',
#  '_EcalBarrelScFiClusters_shapeParameters',
#  '_EcalBarrelScFiClusters_hitContributions',
#  '_EcalBarrelScFiClusters_subdetectorEnergies',
#  'EcalBarrelScFiNAttenuatedHitContributions',
#  '_EcalBarrelScFiNAttenuatedHitContributions_particle',
#  'EcalBarrelScFiNAttenuatedHits',
#  '_EcalBarrelScFiNAttenuatedHits_contributions',
#  'EcalBarrelScFiPAttenuatedHitContributions',
#  '_EcalBarrelScFiPAttenuatedHitContributions_particle',
#  'EcalBarrelScFiPAttenuatedHits',
#  '_EcalBarrelScFiPAttenuatedHits_contributions',
#  'EcalBarrelScFiRawHitAssociations',
#  '_EcalBarrelScFiRawHitAssociations_rawHit',
#  '_EcalBarrelScFiRawHitAssociations_simHit',
#  'EcalBarrelScFiRawHits',
#  'EcalBarrelScFiRecHits',
#  '_EcalBarrelScFiRecHits_rawHit',
#  'EcalBarrelTrackClusterMatches',
#  '_EcalBarrelTrackClusterMatches_cluster',
#  '_EcalBarrelTrackClusterMatches_track',
#  'EcalBarrelTruthClusterAssociations',
#  '_EcalBarrelTruthClusterAssociations_rec',
#  '_EcalBarrelTruthClusterAssociations_sim',
#  'EcalBarrelTruthClusters',
#  '_EcalBarrelTruthClusters_clusters',
#  '_EcalBarrelTruthClusters_hits',
#  '_EcalBarrelTruthClusters_particleIDs',
#  '_EcalBarrelTruthClusters_shapeParameters',
#  '_EcalBarrelTruthClusters_hitContributions',
#  '_EcalBarrelTruthClusters_subdetectorEnergies',
#  'EcalEndcapNClusterAssociations',
#  '_EcalEndcapNClusterAssociations_rec',
#  '_EcalEndcapNClusterAssociations_sim',
#  'EcalEndcapNClusters',
#  '_EcalEndcapNClusters_clusters',
#  '_EcalEndcapNClusters_hits',
#  '_EcalEndcapNClusters_particleIDs',
#  '_EcalEndcapNClusters_shapeParameters',
#  '_EcalEndcapNClusters_hitContributions',
#  '_EcalEndcapNClusters_subdetectorEnergies',
#  'EcalEndcapNRawHitAssociations',
#  '_EcalEndcapNRawHitAssociations_rawHit',
#  '_EcalEndcapNRawHitAssociations_simHit',
#  'EcalEndcapNRawHits',
#  'EcalEndcapNRecHits',
#  '_EcalEndcapNRecHits_rawHit',
#  'EcalEndcapNSplitMergeClusterAssociations',
#  '_EcalEndcapNSplitMergeClusterAssociations_rec',
#  '_EcalEndcapNSplitMergeClusterAssociations_sim',
#  'EcalEndcapNSplitMergeClusters',
#  '_EcalEndcapNSplitMergeClusters_clusters',
#  '_EcalEndcapNSplitMergeClusters_hits',
#  '_EcalEndcapNSplitMergeClusters_particleIDs',
#  '_EcalEndcapNSplitMergeClusters_shapeParameters',
#  '_EcalEndcapNSplitMergeClusters_hitContributions',
#  '_EcalEndcapNSplitMergeClusters_subdetectorEnergies',
#  'EcalEndcapNTrackClusterMatches',
#  '_EcalEndcapNTrackClusterMatches_cluster',
#  '_EcalEndcapNTrackClusterMatches_track',
#  'EcalEndcapNTruthClusterAssociations',
#  '_EcalEndcapNTruthClusterAssociations_rec',
#  '_EcalEndcapNTruthClusterAssociations_sim',
#  'EcalEndcapNTruthClusters',
#  '_EcalEndcapNTruthClusters_clusters',
#  '_EcalEndcapNTruthClusters_hits',
#  '_EcalEndcapNTruthClusters_particleIDs',
#  '_EcalEndcapNTruthClusters_shapeParameters',
#  '_EcalEndcapNTruthClusters_hitContributions',
#  '_EcalEndcapNTruthClusters_subdetectorEnergies',
#  'EcalEndcapPClusterAssociations',
#  '_EcalEndcapPClusterAssociations_rec',
#  '_EcalEndcapPClusterAssociations_sim',
#  'EcalEndcapPClusters',
#  '_EcalEndcapPClusters_clusters',
#  '_EcalEndcapPClusters_hits',
#  '_EcalEndcapPClusters_particleIDs',
#  '_EcalEndcapPClusters_shapeParameters',
#  '_EcalEndcapPClusters_hitContributions',
#  '_EcalEndcapPClusters_subdetectorEnergies',
#  'EcalEndcapPRawHitAssociations',
#  '_EcalEndcapPRawHitAssociations_rawHit',
#  '_EcalEndcapPRawHitAssociations_simHit',
#  'EcalEndcapPRawHits',
#  'EcalEndcapPRecHits',
#  '_EcalEndcapPRecHits_rawHit',
#  'EcalEndcapPSplitMergeClusterAssociations',
#  '_EcalEndcapPSplitMergeClusterAssociations_rec',
#  '_EcalEndcapPSplitMergeClusterAssociations_sim',
#  'EcalEndcapPSplitMergeClusters',
#  '_EcalEndcapPSplitMergeClusters_clusters',
#  '_EcalEndcapPSplitMergeClusters_hits',
#  '_EcalEndcapPSplitMergeClusters_particleIDs',
#  '_EcalEndcapPSplitMergeClusters_shapeParameters',
#  '_EcalEndcapPSplitMergeClusters_hitContributions',
#  '_EcalEndcapPSplitMergeClusters_subdetectorEnergies',
#  'EcalEndcapPTrackClusterMatches',
#  '_EcalEndcapPTrackClusterMatches_cluster',
#  '_EcalEndcapPTrackClusterMatches_track',
#  'EcalEndcapPTruthClusterAssociations',
#  '_EcalEndcapPTruthClusterAssociations_rec',
#  '_EcalEndcapPTruthClusterAssociations_sim',
#  'EcalEndcapPTruthClusters',
#  '_EcalEndcapPTruthClusters_clusters',
#  '_EcalEndcapPTruthClusters_hits',
#  '_EcalEndcapPTruthClusters_particleIDs',
#  '_EcalEndcapPTruthClusters_shapeParameters',
#  '_EcalEndcapPTruthClusters_hitContributions',
#  '_EcalEndcapPTruthClusters_subdetectorEnergies',
#  'EcalFarForwardZDCClusterAssociations',
#  '_EcalFarForwardZDCClusterAssociations_rec',
#  '_EcalFarForwardZDCClusterAssociations_sim',
#  'EcalFarForwardZDCClusters',
#  '_EcalFarForwardZDCClusters_clusters',
#  '_EcalFarForwardZDCClusters_hits',
#  '_EcalFarForwardZDCClusters_particleIDs',
#  '_EcalFarForwardZDCClusters_shapeParameters',
#  '_EcalFarForwardZDCClusters_hitContributions',
#  '_EcalFarForwardZDCClusters_subdetectorEnergies',
#  'EcalFarForwardZDCRawHitAssociations',
#  '_EcalFarForwardZDCRawHitAssociations_rawHit',
#  '_EcalFarForwardZDCRawHitAssociations_simHit',
#  'EcalFarForwardZDCRawHits',
#  'EcalFarForwardZDCRecHits',
#  '_EcalFarForwardZDCRecHits_rawHit',
#  'EcalFarForwardZDCTruthClusterAssociations',
#  '_EcalFarForwardZDCTruthClusterAssociations_rec',
#  '_EcalFarForwardZDCTruthClusterAssociations_sim',
#  'EcalFarForwardZDCTruthClusters',
#  '_EcalFarForwardZDCTruthClusters_clusters',
#  '_EcalFarForwardZDCTruthClusters_hits',
#  '_EcalFarForwardZDCTruthClusters_particleIDs',
#  '_EcalFarForwardZDCTruthClusters_shapeParameters',
#  '_EcalFarForwardZDCTruthClusters_hitContributions',
#  '_EcalFarForwardZDCTruthClusters_subdetectorEnergies',
#  'EcalLumiSpecClusterAssociations',
#  '_EcalLumiSpecClusterAssociations_rec',
#  '_EcalLumiSpecClusterAssociations_sim',
#  'EcalLumiSpecClusters',
#  '_EcalLumiSpecClusters_clusters',
#  '_EcalLumiSpecClusters_hits',
#  '_EcalLumiSpecClusters_particleIDs',
#  '_EcalLumiSpecClusters_shapeParameters',
#  '_EcalLumiSpecClusters_hitContributions',
#  '_EcalLumiSpecClusters_subdetectorEnergies',
#  'EcalLumiSpecRawHitAssociations',
#  '_EcalLumiSpecRawHitAssociations_rawHit',
#  '_EcalLumiSpecRawHitAssociations_simHit',
#  'EcalLumiSpecRawHits',
#  'EcalLumiSpecRecHits',
#  '_EcalLumiSpecRecHits_rawHit',
#  'EcalLumiSpecTruthClusterAssociations',
#  '_EcalLumiSpecTruthClusterAssociations_rec',
#  '_EcalLumiSpecTruthClusterAssociations_sim',
#  'EcalLumiSpecTruthClusters',
#  '_EcalLumiSpecTruthClusters_clusters',
#  '_EcalLumiSpecTruthClusters_hits',
#  '_EcalLumiSpecTruthClusters_particleIDs',
#  '_EcalLumiSpecTruthClusters_shapeParameters',
#  '_EcalLumiSpecTruthClusters_hitContributions',
#  '_EcalLumiSpecTruthClusters_subdetectorEnergies',
#  'EventHeader',
#  '_EventHeader_weights',
#  'ForwardMPGDEndcapHits',
#  '_ForwardMPGDEndcapHits_particle',
#  'ForwardMPGDEndcapRawHitAssociations',
#  '_ForwardMPGDEndcapRawHitAssociations_rawHit',
#  '_ForwardMPGDEndcapRawHitAssociations_simHit',
#  'ForwardMPGDEndcapRawHits',
#  'ForwardMPGDEndcapRecHits',
#  '_ForwardMPGDEndcapRecHits_rawHit',
#  'ForwardOffMRecParticles',
#  '_ForwardOffMRecParticles_clusters',
#  '_ForwardOffMRecParticles_tracks',
#  '_ForwardOffMRecParticles_particles',
#  '_ForwardOffMRecParticles_particleIDs',
#  '_ForwardOffMRecParticles_startVertex',
#  '_ForwardOffMRecParticles_particleIDUsed',
#  'ForwardOffMTrackerRawHitAssociations',
#  '_ForwardOffMTrackerRawHitAssociations_rawHit',
#  '_ForwardOffMTrackerRawHitAssociations_simHit',
#  'ForwardOffMTrackerRawHits',
#  'ForwardOffMTrackerRecHits',
#  '_ForwardOffMTrackerRecHits_rawHit',
#  'ForwardRomanPotRawHitAssociations',
#  '_ForwardRomanPotRawHitAssociations_rawHit',
#  '_ForwardRomanPotRawHitAssociations_simHit',
#  'ForwardRomanPotRawHits',
#  'ForwardRomanPotRecHits',
#  '_ForwardRomanPotRecHits_rawHit',
#  'ForwardRomanPotRecParticles',
#  '_ForwardRomanPotRecParticles_clusters',
#  '_ForwardRomanPotRecParticles_tracks',
#  '_ForwardRomanPotRecParticles_particles',
#  '_ForwardRomanPotRecParticles_particleIDs',
#  '_ForwardRomanPotRecParticles_startVertex',
#  '_ForwardRomanPotRecParticles_particleIDUsed',
#  'GeneratedBreitFrameParticles',
#  '_GeneratedBreitFrameParticles_clusters',
#  '_GeneratedBreitFrameParticles_tracks',
#  '_GeneratedBreitFrameParticles_particles',
#  '_GeneratedBreitFrameParticles_particleIDs',
#  '_GeneratedBreitFrameParticles_startVertex',
#  '_GeneratedBreitFrameParticles_particleIDUsed',
#  'GeneratedCentauroJets',
#  '_GeneratedCentauroJets_clusters',
#  '_GeneratedCentauroJets_tracks',
#  '_GeneratedCentauroJets_particles',
#  '_GeneratedCentauroJets_particleIDs',
#  '_GeneratedCentauroJets_startVertex',
#  '_GeneratedCentauroJets_particleIDUsed',
#  'GeneratedChargedJets',
#  '_GeneratedChargedJets_clusters',
#  '_GeneratedChargedJets_tracks',
#  '_GeneratedChargedJets_particles',
#  '_GeneratedChargedJets_particleIDs',
#  '_GeneratedChargedJets_startVertex',
#  '_GeneratedChargedJets_particleIDUsed',
#  'GeneratedJets',
#  '_GeneratedJets_clusters',
#  '_GeneratedJets_tracks',
#  '_GeneratedJets_particles',
#  '_GeneratedJets_particleIDs',
#  '_GeneratedJets_startVertex',
#  '_GeneratedJets_particleIDUsed',
#  'GeneratedParticles',
#  '_GeneratedParticles_clusters',
#  '_GeneratedParticles_tracks',
#  '_GeneratedParticles_particles',
#  '_GeneratedParticles_particleIDs',
#  '_GeneratedParticles_startVertex',
#  '_GeneratedParticles_particleIDUsed',
#  'HadronicFinalState',
#  '_HadronicFinalState_hadrons',
#  'HcalBarrelClusterAssociations',
#  '_HcalBarrelClusterAssociations_rec',
#  '_HcalBarrelClusterAssociations_sim',
#  'HcalBarrelClusters',
#  '_HcalBarrelClusters_clusters',
#  '_HcalBarrelClusters_hits',
#  '_HcalBarrelClusters_particleIDs',
#  '_HcalBarrelClusters_shapeParameters',
#  '_HcalBarrelClusters_hitContributions',
#  '_HcalBarrelClusters_subdetectorEnergies',
#  'HcalBarrelMergedHits',
#  '_HcalBarrelMergedHits_rawHit',
#  'HcalBarrelRawHitAssociations',
#  '_HcalBarrelRawHitAssociations_rawHit',
#  '_HcalBarrelRawHitAssociations_simHit',
#  'HcalBarrelRawHits',
#  'HcalBarrelRecHits',
#  '_HcalBarrelRecHits_rawHit',
#  'HcalBarrelSplitMergeClusterAssociations',
#  '_HcalBarrelSplitMergeClusterAssociations_rec',
#  '_HcalBarrelSplitMergeClusterAssociations_sim',
#  'HcalBarrelSplitMergeClusters',
#  '_HcalBarrelSplitMergeClusters_clusters',
#  '_HcalBarrelSplitMergeClusters_hits',
#  '_HcalBarrelSplitMergeClusters_particleIDs',
#  '_HcalBarrelSplitMergeClusters_shapeParameters',
#  '_HcalBarrelSplitMergeClusters_hitContributions',
#  '_HcalBarrelSplitMergeClusters_subdetectorEnergies',
#  'HcalBarrelTrackClusterMatches',
#  '_HcalBarrelTrackClusterMatches_cluster',
#  '_HcalBarrelTrackClusterMatches_track',
#  'HcalBarrelTruthClusterAssociations',
#  '_HcalBarrelTruthClusterAssociations_rec',
#  '_HcalBarrelTruthClusterAssociations_sim',
#  'HcalBarrelTruthClusters',
#  '_HcalBarrelTruthClusters_clusters',
#  '_HcalBarrelTruthClusters_hits',
#  '_HcalBarrelTruthClusters_particleIDs',
#  '_HcalBarrelTruthClusters_shapeParameters',
#  '_HcalBarrelTruthClusters_hitContributions',
#  '_HcalBarrelTruthClusters_subdetectorEnergies',
#  'HcalEndcapNClusterAssociations',
#  '_HcalEndcapNClusterAssociations_rec',
#  '_HcalEndcapNClusterAssociations_sim',
#  'HcalEndcapNClusters',
#  '_HcalEndcapNClusters_clusters',
#  '_HcalEndcapNClusters_hits',
#  '_HcalEndcapNClusters_particleIDs',
#  '_HcalEndcapNClusters_shapeParameters',
#  '_HcalEndcapNClusters_hitContributions',
#  '_HcalEndcapNClusters_subdetectorEnergies',
#  'HcalEndcapNMergedHits',
#  '_HcalEndcapNMergedHits_rawHit',
#  'HcalEndcapNRawHitAssociations',
#  '_HcalEndcapNRawHitAssociations_rawHit',
#  '_HcalEndcapNRawHitAssociations_simHit',
#  'HcalEndcapNRawHits',
#  'HcalEndcapNRecHits',
#  '_HcalEndcapNRecHits_rawHit',
#  'HcalEndcapNSplitMergeClusterAssociations',
#  '_HcalEndcapNSplitMergeClusterAssociations_rec',
#  '_HcalEndcapNSplitMergeClusterAssociations_sim',
#  'HcalEndcapNSplitMergeClusters',
#  '_HcalEndcapNSplitMergeClusters_clusters',
#  '_HcalEndcapNSplitMergeClusters_hits',
#  '_HcalEndcapNSplitMergeClusters_particleIDs',
#  '_HcalEndcapNSplitMergeClusters_shapeParameters',
#  '_HcalEndcapNSplitMergeClusters_hitContributions',
#  '_HcalEndcapNSplitMergeClusters_subdetectorEnergies',
#  'HcalEndcapNTrackClusterMatches',
#  '_HcalEndcapNTrackClusterMatches_cluster',
#  '_HcalEndcapNTrackClusterMatches_track',
#  'HcalEndcapNTruthClusterAssociations',
#  '_HcalEndcapNTruthClusterAssociations_rec',
#  '_HcalEndcapNTruthClusterAssociations_sim',
#  'HcalEndcapNTruthClusters',
#  '_HcalEndcapNTruthClusters_clusters',
#  '_HcalEndcapNTruthClusters_hits',
#  '_HcalEndcapNTruthClusters_particleIDs',
#  '_HcalEndcapNTruthClusters_shapeParameters',
#  '_HcalEndcapNTruthClusters_hitContributions',
#  '_HcalEndcapNTruthClusters_subdetectorEnergies',
#  'HcalEndcapPInsertClusterAssociations',
#  '_HcalEndcapPInsertClusterAssociations_rec',
#  '_HcalEndcapPInsertClusterAssociations_sim',
#  'HcalEndcapPInsertClusters',
#  '_HcalEndcapPInsertClusters_clusters',
#  '_HcalEndcapPInsertClusters_hits',
#  '_HcalEndcapPInsertClusters_particleIDs',
#  '_HcalEndcapPInsertClusters_shapeParameters',
#  '_HcalEndcapPInsertClusters_hitContributions',
#  '_HcalEndcapPInsertClusters_subdetectorEnergies',
#  'HcalEndcapPInsertMergedHits',
#  '_HcalEndcapPInsertMergedHits_rawHit',
#  'HcalEndcapPInsertRawHitAssociations',
#  '_HcalEndcapPInsertRawHitAssociations_rawHit',
#  '_HcalEndcapPInsertRawHitAssociations_simHit',
#  'HcalEndcapPInsertRawHits',
#  'HcalEndcapPInsertRecHits',
#  '_HcalEndcapPInsertRecHits_rawHit',
#  'HcalFarForwardZDCClusterAssociations',
#  '_HcalFarForwardZDCClusterAssociations_rec',
#  '_HcalFarForwardZDCClusterAssociations_sim',
#  'HcalFarForwardZDCClusterAssociationsBaseline',
#  '_HcalFarForwardZDCClusterAssociationsBaseline_rec',
#  '_HcalFarForwardZDCClusterAssociationsBaseline_sim',
#  'HcalFarForwardZDCClusters',
#  '_HcalFarForwardZDCClusters_clusters',
#  '_HcalFarForwardZDCClusters_hits',
#  '_HcalFarForwardZDCClusters_particleIDs',
#  '_HcalFarForwardZDCClusters_shapeParameters',
#  '_HcalFarForwardZDCClusters_hitContributions',
#  '_HcalFarForwardZDCClusters_subdetectorEnergies',
#  'HcalFarForwardZDCClustersBaseline',
#  '_HcalFarForwardZDCClustersBaseline_clusters',
#  '_HcalFarForwardZDCClustersBaseline_hits',
#  '_HcalFarForwardZDCClustersBaseline_particleIDs',
#  '_HcalFarForwardZDCClustersBaseline_shapeParameters',
#  '_HcalFarForwardZDCClustersBaseline_hitContributions',
#  '_HcalFarForwardZDCClustersBaseline_subdetectorEnergies',
#  'HcalFarForwardZDCRawHitAssociations',
#  '_HcalFarForwardZDCRawHitAssociations_rawHit',
#  '_HcalFarForwardZDCRawHitAssociations_simHit',
#  'HcalFarForwardZDCRawHits',
#  'HcalFarForwardZDCRecHits',
#  '_HcalFarForwardZDCRecHits_rawHit',
#  'HcalFarForwardZDCSubcellHits',
#  '_HcalFarForwardZDCSubcellHits_rawHit',
#  'HcalFarForwardZDCTruthClusterAssociations',
#  '_HcalFarForwardZDCTruthClusterAssociations_rec',
#  '_HcalFarForwardZDCTruthClusterAssociations_sim',
#  'HcalFarForwardZDCTruthClusters',
#  '_HcalFarForwardZDCTruthClusters_clusters',
#  '_HcalFarForwardZDCTruthClusters_hits',
#  '_HcalFarForwardZDCTruthClusters_particleIDs',
#  '_HcalFarForwardZDCTruthClusters_shapeParameters',
#  '_HcalFarForwardZDCTruthClusters_hitContributions',
#  '_HcalFarForwardZDCTruthClusters_subdetectorEnergies',
#  'InclusiveKinematicsDA',
#  '_InclusiveKinematicsDA_scat',
#  'InclusiveKinematicsElectron',
#  '_InclusiveKinematicsElectron_scat',
#  'InclusiveKinematicsESigma',
#  '_InclusiveKinematicsESigma_scat',
#  'InclusiveKinematicseSigma_objIdx',
#  'InclusiveKinematicsJB',
#  '_InclusiveKinematicsJB_scat',
#  'InclusiveKinematicsML',
#  '_InclusiveKinematicsML_scat',
#  'InclusiveKinematicsSigma',
#  '_InclusiveKinematicsSigma_scat',
#  'InclusiveKinematicsTruth',
#  '_InclusiveKinematicsTruth_scat',
#  'LFHCALClusterAssociations',
#  '_LFHCALClusterAssociations_rec',
#  '_LFHCALClusterAssociations_sim',
#  'LFHCALClusters',
#  '_LFHCALClusters_clusters',
#  '_LFHCALClusters_hits',
#  '_LFHCALClusters_particleIDs',
#  '_LFHCALClusters_shapeParameters',
#  '_LFHCALClusters_hitContributions',
#  '_LFHCALClusters_subdetectorEnergies',
#  'LFHCALRawHitAssociations',
#  '_LFHCALRawHitAssociations_rawHit',
#  '_LFHCALRawHitAssociations_simHit',
#  'LFHCALRawHits',
#  'LFHCALRecHits',
#  '_LFHCALRecHits_rawHit',
#  'LFHCALSplitMergeClusterAssociations',
#  '_LFHCALSplitMergeClusterAssociations_rec',
#  '_LFHCALSplitMergeClusterAssociations_sim',
#  'LFHCALSplitMergeClusters',
#  '_LFHCALSplitMergeClusters_clusters',
#  '_LFHCALSplitMergeClusters_hits',
#  '_LFHCALSplitMergeClusters_particleIDs',
#  '_LFHCALSplitMergeClusters_shapeParameters',
#  '_LFHCALSplitMergeClusters_hitContributions',
#  '_LFHCALSplitMergeClusters_subdetectorEnergies',
#  'LFHCALTrackClusterMatches',
#  '_LFHCALTrackClusterMatches_cluster',
#  '_LFHCALTrackClusterMatches_track',
#  'MCBeamElectrons_objIdx',
#  'MCBeamProtons_objIdx',
#  'MCNonScatteredElectronAssociations_objIdx',
#  'MCParticles',
#  '_MCParticles_parents',
#  '_MCParticles_daughters',
#  'MCParticlesHeadOnFrameNoBeamFX',
#  '_MCParticlesHeadOnFrameNoBeamFX_parents',
#  '_MCParticlesHeadOnFrameNoBeamFX_daughters',
#  'MCScatteredElectronAssociations_objIdx',
#  'MCScatteredElectrons_objIdx',
#  'MCScatteredProtons_objIdx',
#  'MPGDBarrelHits',
#  '_MPGDBarrelHits_particle',
#  'MPGDBarrelRawHitAssociations',
#  '_MPGDBarrelRawHitAssociations_rawHit',
#  '_MPGDBarrelRawHitAssociations_simHit',
#  'MPGDBarrelRawHits',
#  'MPGDBarrelRecHits',
#  '_MPGDBarrelRecHits_rawHit',
#  'OuterMPGDBarrelHits',
#  '_OuterMPGDBarrelHits_particle',
#  'OuterMPGDBarrelRawHitAssociations',
#  '_OuterMPGDBarrelRawHitAssociations_rawHit',
#  '_OuterMPGDBarrelRawHitAssociations_simHit',
#  'OuterMPGDBarrelRawHits',
#  'OuterMPGDBarrelRecHits',
#  '_OuterMPGDBarrelRecHits_rawHit',
#  'PrimaryVertices_objIdx',
#  'ReconstructedBreitFrameParticles',
#  '_ReconstructedBreitFrameParticles_clusters',
#  '_ReconstructedBreitFrameParticles_tracks',
#  '_ReconstructedBreitFrameParticles_particles',
#  '_ReconstructedBreitFrameParticles_particleIDs',
#  '_ReconstructedBreitFrameParticles_startVertex',
#  '_ReconstructedBreitFrameParticles_particleIDUsed',
#  'ReconstructedCentauroJets',
#  '_ReconstructedCentauroJets_clusters',
#  '_ReconstructedCentauroJets_tracks',
#  '_ReconstructedCentauroJets_particles',
#  '_ReconstructedCentauroJets_particleIDs',
#  '_ReconstructedCentauroJets_startVertex',
#  '_ReconstructedCentauroJets_particleIDUsed',
#  'ReconstructedChargedJets',
#  '_ReconstructedChargedJets_clusters',
#  '_ReconstructedChargedJets_tracks',
#  '_ReconstructedChargedJets_particles',
#  '_ReconstructedChargedJets_particleIDs',
#  '_ReconstructedChargedJets_startVertex',
#  '_ReconstructedChargedJets_particleIDUsed',
#  'ReconstructedChargedParticleAssociations',
#  '_ReconstructedChargedParticleAssociations_rec',
#  '_ReconstructedChargedParticleAssociations_sim',
#  'ReconstructedChargedParticles',
#  '_ReconstructedChargedParticles_clusters',
#  '_ReconstructedChargedParticles_tracks',
#  '_ReconstructedChargedParticles_particles',
#  '_ReconstructedChargedParticles_particleIDs',
#  '_ReconstructedChargedParticles_startVertex',
#  '_ReconstructedChargedParticles_particleIDUsed',
#  'ReconstructedChargedRealPIDParticleIDs',
#  '_ReconstructedChargedRealPIDParticleIDs_particle',
#  '_ReconstructedChargedRealPIDParticleIDs_parameters',
#  'ReconstructedChargedRealPIDParticles',
#  '_ReconstructedChargedRealPIDParticles_clusters',
#  '_ReconstructedChargedRealPIDParticles_tracks',
#  '_ReconstructedChargedRealPIDParticles_particles',
#  '_ReconstructedChargedRealPIDParticles_particleIDs',
#  '_ReconstructedChargedRealPIDParticles_startVertex',
#  '_ReconstructedChargedRealPIDParticles_particleIDUsed',
#  'ReconstructedElectrons_objIdx',
#  'ReconstructedFarForwardZDCLambdaDecayProductsCM',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_clusters',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_tracks',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_particles',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_particleIDs',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_startVertex',
#  '_ReconstructedFarForwardZDCLambdaDecayProductsCM_particleIDUsed',
#  'ReconstructedFarForwardZDCLambdas',
#  '_ReconstructedFarForwardZDCLambdas_clusters',
#  '_ReconstructedFarForwardZDCLambdas_tracks',
#  '_ReconstructedFarForwardZDCLambdas_particles',
#  '_ReconstructedFarForwardZDCLambdas_particleIDs',
#  '_ReconstructedFarForwardZDCLambdas_startVertex',
#  '_ReconstructedFarForwardZDCLambdas_particleIDUsed',
#  'ReconstructedFarForwardZDCNeutrals',
#  '_ReconstructedFarForwardZDCNeutrals_clusters',
#  '_ReconstructedFarForwardZDCNeutrals_tracks',
#  '_ReconstructedFarForwardZDCNeutrals_particles',
#  '_ReconstructedFarForwardZDCNeutrals_particleIDs',
#  '_ReconstructedFarForwardZDCNeutrals_startVertex',
#  '_ReconstructedFarForwardZDCNeutrals_particleIDUsed',
#  'ReconstructedJets',
#  '_ReconstructedJets_clusters',
#  '_ReconstructedJets_tracks',
#  '_ReconstructedJets_particles',
#  '_ReconstructedJets_particleIDs',
#  '_ReconstructedJets_startVertex',
#  '_ReconstructedJets_particleIDUsed',
#  'ReconstructedParticleAssociations',
#  '_ReconstructedParticleAssociations_rec',
#  '_ReconstructedParticleAssociations_sim',
#  'ReconstructedParticles',
#  '_ReconstructedParticles_clusters',
#  '_ReconstructedParticles_tracks',
#  '_ReconstructedParticles_particles',
#  '_ReconstructedParticles_particleIDs',
#  '_ReconstructedParticles_startVertex',
#  '_ReconstructedParticles_particleIDUsed',
#  'ReconstructedTruthSeededChargedParticleAssociations',
#  '_ReconstructedTruthSeededChargedParticleAssociations_rec',
#  '_ReconstructedTruthSeededChargedParticleAssociations_sim',
#  'ReconstructedTruthSeededChargedParticles',
#  '_ReconstructedTruthSeededChargedParticles_clusters',
#  '_ReconstructedTruthSeededChargedParticles_tracks',
#  '_ReconstructedTruthSeededChargedParticles_particles',
#  '_ReconstructedTruthSeededChargedParticles_particleIDs',
#  '_ReconstructedTruthSeededChargedParticles_startVertex',
#  '_ReconstructedTruthSeededChargedParticles_particleIDUsed',
#  'RICHEndcapNParticleIDs',
#  '_RICHEndcapNParticleIDs_particle',
#  '_RICHEndcapNParticleIDs_parameters',
#  'RICHEndcapNRawHits',
#  'RICHEndcapNRawHitsAssociations',
#  '_RICHEndcapNRawHitsAssociations_rawHit',
#  '_RICHEndcapNRawHitsAssociations_simHit',
#  'RICHEndcapNTruthSeededParticleIDs',
#  '_RICHEndcapNTruthSeededParticleIDs_particle',
#  '_RICHEndcapNTruthSeededParticleIDs_parameters',
#  'ScatteredElectronsEMinusPz_objIdx',
#  'ScatteredElectronsTruth_objIdx',
#  'SiBarrelHits',
#  '_SiBarrelHits_particle',
#  'SiBarrelRawHitAssociations',
#  '_SiBarrelRawHitAssociations_rawHit',
#  '_SiBarrelRawHitAssociations_simHit',
#  'SiBarrelRawHits',
#  'SiBarrelTrackerRecHits',
#  '_SiBarrelTrackerRecHits_rawHit',
#  'SiBarrelVertexRawHitAssociations',
#  '_SiBarrelVertexRawHitAssociations_rawHit',
#  '_SiBarrelVertexRawHitAssociations_simHit',
#  'SiBarrelVertexRawHits',
#  'SiBarrelVertexRecHits',
#  '_SiBarrelVertexRecHits_rawHit',
#  'SiEndcapTrackerRawHitAssociations',
#  '_SiEndcapTrackerRawHitAssociations_rawHit',
#  '_SiEndcapTrackerRawHitAssociations_simHit',
#  'SiEndcapTrackerRawHits',
#  'SiEndcapTrackerRecHits',
#  '_SiEndcapTrackerRecHits_rawHit',
#  'TaggerTrackerCombinedPulses',
#  '_TaggerTrackerCombinedPulses_calorimeterHits',
#  '_TaggerTrackerCombinedPulses_trackerHits',
#  '_TaggerTrackerCombinedPulses_pulses',
#  '_TaggerTrackerCombinedPulses_particles',
#  '_TaggerTrackerCombinedPulses_amplitude',
#  'TaggerTrackerCombinedPulsesWithNoise',
#  '_TaggerTrackerCombinedPulsesWithNoise_calorimeterHits',
#  '_TaggerTrackerCombinedPulsesWithNoise_trackerHits',
#  '_TaggerTrackerCombinedPulsesWithNoise_pulses',
#  '_TaggerTrackerCombinedPulsesWithNoise_particles',
#  '_TaggerTrackerCombinedPulsesWithNoise_amplitude',
#  'TaggerTrackerHitPulses',
#  '_TaggerTrackerHitPulses_calorimeterHits',
#  '_TaggerTrackerHitPulses_trackerHits',
#  '_TaggerTrackerHitPulses_pulses',
#  '_TaggerTrackerHitPulses_particles',
#  '_TaggerTrackerHitPulses_amplitude',
#  'TaggerTrackerHits',
#  '_TaggerTrackerHits_particle',
#  'TaggerTrackerLocalTrackAssociations_objIdx',
#  'TaggerTrackerLocalTracks_objIdx',
#  'TaggerTrackerM1L0ClusterPositions',
#  '_TaggerTrackerM1L0ClusterPositions_hits',
#  '_TaggerTrackerM1L0ClusterPositions_weights',
#  'TaggerTrackerM1L1ClusterPositions',
#  '_TaggerTrackerM1L1ClusterPositions_hits',
#  '_TaggerTrackerM1L1ClusterPositions_weights',
#  'TaggerTrackerM1L2ClusterPositions',
#  '_TaggerTrackerM1L2ClusterPositions_hits',
#  '_TaggerTrackerM1L2ClusterPositions_weights',
#  'TaggerTrackerM1L3ClusterPositions',
#  '_TaggerTrackerM1L3ClusterPositions_hits',
#  '_TaggerTrackerM1L3ClusterPositions_weights',
#  'TaggerTrackerM1LocalTrackAssociations',
#  '_TaggerTrackerM1LocalTrackAssociations_rec',
#  '_TaggerTrackerM1LocalTrackAssociations_sim',
#  'TaggerTrackerM1LocalTracks',
#  '_TaggerTrackerM1LocalTracks_measurements',
#  '_TaggerTrackerM1LocalTracks_tracks',
#  '_TaggerTrackerM1LocalTracks_trajectory',
#  'TaggerTrackerM2L0ClusterPositions',
#  '_TaggerTrackerM2L0ClusterPositions_hits',
#  '_TaggerTrackerM2L0ClusterPositions_weights',
#  'TaggerTrackerM2L1ClusterPositions',
#  '_TaggerTrackerM2L1ClusterPositions_hits',
#  '_TaggerTrackerM2L1ClusterPositions_weights',
#  'TaggerTrackerM2L2ClusterPositions',
#  '_TaggerTrackerM2L2ClusterPositions_hits',
#  '_TaggerTrackerM2L2ClusterPositions_weights',
#  'TaggerTrackerM2L3ClusterPositions',
#  '_TaggerTrackerM2L3ClusterPositions_hits',
#  '_TaggerTrackerM2L3ClusterPositions_weights',
#  'TaggerTrackerM2LocalTrackAssociations',
#  '_TaggerTrackerM2LocalTrackAssociations_rec',
#  '_TaggerTrackerM2LocalTrackAssociations_sim',
#  'TaggerTrackerM2LocalTracks',
#  '_TaggerTrackerM2LocalTracks_measurements',
#  '_TaggerTrackerM2LocalTracks_tracks',
#  '_TaggerTrackerM2LocalTracks_trajectory',
#  'TaggerTrackerRawHitAssociations',
#  '_TaggerTrackerRawHitAssociations_rawHit',
#  '_TaggerTrackerRawHitAssociations_simHit',
#  'TaggerTrackerRawHits',
#  'TaggerTrackerReconstructedParticleAssociations',
#  '_TaggerTrackerReconstructedParticleAssociations_rec',
#  '_TaggerTrackerReconstructedParticleAssociations_sim',
#  'TaggerTrackerReconstructedParticles',
#  '_TaggerTrackerReconstructedParticles_clusters',
#  '_TaggerTrackerReconstructedParticles_tracks',
#  '_TaggerTrackerReconstructedParticles_particles',
#  '_TaggerTrackerReconstructedParticles_particleIDs',
#  '_TaggerTrackerReconstructedParticles_startVertex',
#  '_TaggerTrackerReconstructedParticles_particleIDUsed',
#  'TaggerTrackerSharedHits',
#  '_TaggerTrackerSharedHits_particle',
#  'TOFBarrelADCTDC',
#  'TOFBarrelClusterHits',
#  '_TOFBarrelClusterHits_hits',
#  '_TOFBarrelClusterHits_weights',
#  'TOFBarrelHits',
#  '_TOFBarrelHits_particle',
#  'TOFBarrelRawHitAssociations',
#  '_TOFBarrelRawHitAssociations_rawHit',
#  '_TOFBarrelRawHitAssociations_simHit',
#  'TOFBarrelRawHits',
#  'TOFBarrelRecHits',
#  '_TOFBarrelRecHits_rawHit',
#  'TOFEndcapADCTDC',
#  'TOFEndcapHits',
#  '_TOFEndcapHits_particle',
#  'TOFEndcapRawHitAssociations',
#  '_TOFEndcapRawHitAssociations_rawHit',
#  '_TOFEndcapRawHitAssociations_simHit',
#  'TOFEndcapRawHits',
#  'TOFEndcapRecHits',
#  '_TOFEndcapRecHits_rawHit',
#  'TOFEndcapSharedHits',
#  '_TOFEndcapSharedHits_particle',
#  'TrackerEndcapHits',
#  '_TrackerEndcapHits_particle',
#  'VertexBarrelHits',
#  '_VertexBarrelHits_particle',
#  'GPIntKeys',
#  'GPIntValues',
#  'GPFloatKeys',
#  'GPFloatValues',
#  'GPDoubleKeys',
#  'GPDoubleValues',
#  'GPStringKeys',
#  'GPStringValues']

# %%
tree.keys(filter_name="MC*",recursive=False)
# Out:
# ['MCBeamElectrons_objIdx',
#  'MCBeamProtons_objIdx',
#  'MCNonScatteredElectronAssociations_objIdx',
#  'MCParticles',
#  'MCParticlesHeadOnFrameNoBeamFX',
#  'MCScatteredElectronAssociations_objIdx',
#  'MCScatteredElectrons_objIdx',
#  'MCScatteredProtons_objIdx']

# %%
branches=tree["MCParticles"]
branches.keys(recursive=False)
# Out:
# ['MCParticles.PDG',
#  'MCParticles.generatorStatus',
#  'MCParticles.simulatorStatus',
#  'MCParticles.charge',
#  'MCParticles.time',
#  'MCParticles.mass',
#  'MCParticles.vertex.x',
#  'MCParticles.vertex.y',
#  'MCParticles.vertex.z',
#  'MCParticles.endpoint.x',
#  'MCParticles.endpoint.y',
#  'MCParticles.endpoint.z',
#  'MCParticles.momentum.x',
#  'MCParticles.momentum.y',
#  'MCParticles.momentum.z',
#  'MCParticles.momentumAtEndpoint.x',
#  'MCParticles.momentumAtEndpoint.y',
#  'MCParticles.momentumAtEndpoint.z',
#  'MCParticles.spin.x',
#  'MCParticles.spin.y',
#  'MCParticles.spin.z',
#  'MCParticles.colorFlow.a',
#  'MCParticles.colorFlow.b',
#  'MCParticles.parents_begin',
#  'MCParticles.parents_end',
#  'MCParticles.daughters_begin',
#  'MCParticles.daughters_end']

# %%
branch = branches['MCParticles.PDG'].array()
print(branch)
print(len(branch))
# Out:
# [[-13], [-13], [-13, 11], [-13], ..., [-13], [-13, 11, 11], [-13, 11, 11, 11]]
# 50000

# %%
print(tree.num_entries)
# Out:
# 50000

# %%
branches=tree["MCParticles"].arrays()
branches[100]
# Out:
# <Record {'MCParticles.PDG': [-13], ...} type='{"MCParticles.PDG": var * int...'>

# %%
tree = file ['events']
tree.keys()..
# Out:
#   Cell In[127], line 2
#     tree.keys()..
#                 ^
# SyntaxError: invalid syntax

# %%
print(branches[0].tolist())
# Out:
# {'MCParticles.PDG': [-13], 'MCParticles.generatorStatus': [1], 'MCParticles.simulatorStatus': [33554432], 'MCParticles.charge': [1.0], 'MCParticles.time': [0.0], 'MCParticles.mass': [0.1056583715], 'MCParticles.vertex.x': [0.0], 'MCParticles.vertex.y': [0.0], 'MCParticles.vertex.z': [0.0], 'MCParticles.endpoint.x': [-30000.0], 'MCParticles.endpoint.y': [-14194.621300719302], 'MCParticles.endpoint.z': [-15473.966825077414], 'MCParticles.momentum.x': [-14.874989124956478], 'MCParticles.momentum.y': [-6.654445099080852], 'MCParticles.momentum.z': [-7.521198289327957], 'MCParticles.momentumAtEndpoint.x': [-13.430982088291517], 'MCParticles.momentumAtEndpoint.y': [-6.346306642612163], 'MCParticles.momentumAtEndpoint.z': [-6.930888938754872], 'MCParticles.spin.x': [0.0], 'MCParticles.spin.y': [0.0], 'MCParticles.spin.z': [0.0], 'MCParticles.colorFlow.a': [0], 'MCParticles.colorFlow.b': [0], 'MCParticles.parents_begin': [0], 'MCParticles.parents_end': [0], 'MCParticles.daughters_begin': [0], 'MCParticles.daughters_end': [0]}

# %%
branch = branches['MCParticles.PDG']
for i in range (0,10):
    print(branch[i])
# Out:
# [-13]
# [-13]
# [-13, 11]
# [-13]
# [-13]
# [-13]
# [-13]
# [-13]
# [-13, 11, 11, 11]
# [-13]

# %%
pid = tree['MCParticles'].arrays()
plt.hist(ak.flatten(pid['MCParticles.PDG']),bins =200, range=(-25, 25))
plt.show()

# %%
p_x = branches['MCParticles.momentum.x'].arrays()
# print(p_x)
p_y = branches['MCParticles.momentum.y'].arrays()
# print(p_y)
p_z = branches['MCParticles.momentum.z'].arrays()
# print(p_z)

p_x['MCParticles.momentum.x']
p = np.sqrt(p_x['MCParticles.momentum.x']**2+p_y['MCParticles.momentum.y']**2+p_z['MCParticles.momentum.z']**2)
print(p)
plt.hist(ak.flatten(p),bins =100, )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FieldNotFoundError                        Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 p_x = branches['MCParticles.momentum.x'].arrays()
#       2 # print(p_x)
#       3 p_y = branches['MCParticles.momentum.y'].arrays()
#
# File /opt/local/lib/python3.12/site-packages/awkward/highlevel.py:1104, in Array.__getitem__(self, where)
#     675 def __getitem__(self, where):
#     676     """
#     677     Args:
#     678         where (many types supported; see below): Index of positions to
#    (...)
#    1102     have the same dimension as the array being indexed.
#    1103     """
# -> 1104     with ak._errors.SlicingErrorContext(self, where):
#    1105         # Handle named axis
#    1106         (_, ndim) = self._layout.minmax_depth
#    1107         named_axis = _get_named_axis(self)
#
# File /opt/local/lib/python3.12/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File /opt/local/lib/python3.12/site-packages/awkward/highlevel.py:1112, in Array.__getitem__(self, where)
#    1108 where = _normalize_named_slice(named_axis, where, ndim)
#    1110 NamedAxis.mapping = named_axis
# -> 1112 indexed_layout = prepare_layout(self._layout._getitem(where, NamedAxis))
#    1114 if NamedAxis.mapping:
#    1115     return ak.operations.ak_with_named_axis._impl(
#    1116         indexed_layout,
#    1117         named_axis=NamedAxis.mapping,
#    (...)
#    1120         attrs=self._attrs,
#    1121     )
#
# File /opt/local/lib/python3.12/site-packages/awkward/contents/content.py:551, in Content._getitem(self, where, named_axis)
#     548     return self._getitem((where,), named_axis)
#     550 elif isinstance(where, str):
# --> 551     return self._getitem_field(where)
#     553 elif where is np.newaxis:
#     554     return self._getitem((where,), named_axis)
#
# File /opt/local/lib/python3.12/site-packages/awkward/contents/recordarray.py:484, in RecordArray._getitem_field(self, where, only_fields)
#     480 def _getitem_field(
#     481     self, where: str | SupportsIndex, only_fields: tuple[str, ...] = ()
#     482 ) -> Content:
#     483     if len(only_fields) == 0:
# --> 484         return self.content(where)
#     486     else:
#     487         nexthead, nexttail = ak._slicing.head_tail(only_fields)
#
# File /opt/local/lib/python3.12/site-packages/awkward/contents/recordarray.py:417, in RecordArray.content(self, index_or_field)
#     416 def content(self, index_or_field: str | SupportsIndex) -> Content:
# --> 417     out = super().content(index_or_field)
#     418     if (
#     419         self.length is unknown_length
#     420         or out.length is unknown_length
#     421         or out.length == self.length
#     422     ):
#     423         return out
#
# File /opt/local/lib/python3.12/site-packages/awkward/_meta/recordmeta.py:140, in RecordMeta.content(self, index_or_field)
#     138     index = index_or_field
#     139 elif isinstance(index_or_field, str):
# --> 140     index = self.field_to_index(index_or_field)
#     141 else:
#     142     raise TypeError(
#     143         f"index_or_field must be an integer (index) or string (field), not {index_or_field!r}"
#     144     )
#
# File /opt/local/lib/python3.12/site-packages/awkward/_meta/recordmeta.py:121, in RecordMeta.field_to_index(self, field)
#     119     else:
#     120         return i
# --> 121 raise FieldNotFoundError(
#     122     f"no field {field!r} in record with {len(self._contents)} fields"
#     123 )
#
# FieldNotFoundError: no field 'MCParticles.momentum.x' in record with 1 fields
#
# This error occurred while attempting to slice
#
#     <Array [{'MCParticles.PDG': [-13]}, ...] type='50000 * {"MCParticles.PD...'>
#
# with
#
#     'MCParticles.momentum.x'

# %%
tree = file['events']
MCPartBr = tree["MCParticles"].arrays()
MC_Parts = vector.zip({'px': tree["MCParticles.momentum.x"], 'py': tree["MCParticles.momentum.y"], 'pz': tree["MCParticles.momentum.z"]})

print(MC_Parts.eta)
print(MC_Parts.theta)
# Out:
# []
# []

# %%
tree = file['events']
MCPartBr = tree["MCParticles"].arrays()
MC_Parts = vector.zip({'px': MCPartBr["MCParticles.momentum.x"], 'py': MCPartBr["MCParticles.momentum.y"], 'pz': MCPartBr["MCParticles.momentum.z"]})
print(MC_Parts.eta)
print(MC_Parts.theta)
plt.hist(ak.flatten(MC_Parts.eta),bins =100, )
plt.show()
# Out:
# [[-0.447], [-0.612], ..., [-1.11, ..., -0.372], [-1.4, -0.459, -0.749, -0.885]]
# [[2], [2.15], [2.16, ...], ..., [2.5, 2.83, 1.93], [2.66, 2.01, 2.26, 2.36]]

# %%
branch=tree['MCParticles.PDG'].arrays()
# ss = branch['MCParticles.generatorStatus'] == 1
muons_only = branch['MCParticles.PDG'] == -13

branch_px= tree["MCParticles.momentum.x"].arrays()
branch_py= tree["MCParticles.momentum.y"].arrays()
branch_pz= tree["MCParticles.momentum.z"].arrays()
branch_m = tree["MCParticles.mass"].arrays()
# plt.hist(ak.flatten(np.sqrt(branch_m["MCParticles.mass"]**2+branch_px["MCParticles.momentum.x"]**2 + branch_py["MCParticles.momentum.y"]**2 + branch_pz["MCParticles.momentum.z"]**2)), bins=25);
# plt.hist(branch)
selected_px = branch_px["MCParticles.momentum.x"][muons_only]
selected_py = branch_py["MCParticles.momentum.y"][muons_only]
selected_pz = branch_pz["MCParticles.momentum.z"][muons_only]
selected_m = branch_m["MCParticles.mass"][muons_only]
energy = np.sqrt(selected_m**2 + selected_px**2 + selected_py**2 + selected_pz**2)
momentum = np.sqrt(selected_px**2 + selected_py**2 + selected_pz**2)
theta = selected_pz /momentum
eta = -np.log(np.tan(theta)/2)
plt.hist(eta,100);
# Out:
# /opt/local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in log
#   return impl(*broadcasted_args, **(kwargs or {}))
